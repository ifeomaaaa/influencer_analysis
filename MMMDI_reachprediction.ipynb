# %%
import pandas as pd

# %%
df = pd.read_csv("Melswardrobe.csv", encoding="utf-8")

# %%
df.head()
# Out:
#                                    postUrl  \
# 0  https://www.instagram.com/p/Ci3CTjkLyNs
# 1  https://www.instagram.com/p/Ci0vqfnKI58
# 2  https://www.instagram.com/p/Ci22KPwKtBr
# 3  https://www.instagram.com/p/Ci233mIqVch
# 4  https://www.instagram.com/p/Ci21u4rKV_K
#
#                                          description  commentCount  likeCount  \
# 0  Stormzy styled by me in @maisonvalentino for #...            98      23380
# 1  We just step real clean and say Mel made me do...          1712      86221
# 2  Stormzy styled by me in @biancasaunders for #M...            41      13436
# 3  Dina Asher Smith in @area. Styled by me for St...            30      14227
# 4                                                🐐x🐐           499      22599
#
#                     pubDate   type  caption  \
# 0  2022-09-23T18:51:15.000Z  Photo      NaN
# 1  2022-09-22T21:29:52.000Z  Photo      NaN
# 2  2022-09-23T17:05:07.000Z  Photo      NaN
# 3  2022-09-23T17:20:03.000Z  Photo      NaN
# 4  2022-09-23T17:01:55.000Z  Video      NaN
#
#                                               imgUrl  \
# 0  https://scontent-iad3-2.cdninstagram.com/v/t51...
# 1  https://scontent-iad3-2.cdninstagram.com/v/t51...
# 2  https://scontent-iad3-2.cdninstagram.com/v/t51...
# 3  https://scontent-iad3-2.cdninstagram.com/v/t51...
# 4  https://scontent-iad3-2.cdninstagram.com/v/t51...
#
#                                             videoUrl                   id  \
# 0                                                NaN  2933823822206280556
# 1                                                NaN  2933178885672046204
# 2                                                NaN  2933770405899063403
# 3                                                NaN  2933777920355292961
# 4  https://scontent-iad3-2.cdninstagram.com/v/t50...  2933768525693149130
#
#                                     profileUrl                 timestamp  \
# 0  https://www.instagram.com/melissaswardrobe/  2022-09-27T17:19:31.111Z
# 1  https://www.instagram.com/melissaswardrobe/  2022-09-27T17:19:31.111Z
# 2  https://www.instagram.com/melissaswardrobe/  2022-09-27T17:19:31.111Z
# 3  https://www.instagram.com/melissaswardrobe/  2022-09-27T17:19:31.111Z
# 4  https://www.instagram.com/melissaswardrobe/  2022-09-27T17:19:31.111Z
#
#                                          query  error  message  cookieError
# 0  https://www.instagram.com/melissaswardrobe/    NaN      NaN          NaN
# 1  https://www.instagram.com/melissaswardrobe/    NaN      NaN          NaN
# 2  https://www.instagram.com/melissaswardrobe/    NaN      NaN          NaN
# 3  https://www.instagram.com/melissaswardrobe/    NaN      NaN          NaN
# 4  https://www.instagram.com/melissaswardrobe/    NaN      NaN          NaN

# %%
df.drop(["caption", "imgUrl", "videoUrl", "id", "profileUrl", "query", "error", "message", "cookieError", "timestamp"], axis=1, inplace=True)

# %%
df.head()
# Out:
#                                    postUrl  \
# 0  https://www.instagram.com/p/Ci3CTjkLyNs
# 1  https://www.instagram.com/p/Ci0vqfnKI58
# 2  https://www.instagram.com/p/Ci22KPwKtBr
# 3  https://www.instagram.com/p/Ci233mIqVch
# 4  https://www.instagram.com/p/Ci21u4rKV_K
#
#                                          description  commentCount  likeCount  \
# 0  Stormzy styled by me in @maisonvalentino for #...            98      23380
# 1  We just step real clean and say Mel made me do...          1712      86221
# 2  Stormzy styled by me in @biancasaunders for #M...            41      13436
# 3  Dina Asher Smith in @area. Styled by me for St...            30      14227
# 4                                                🐐x🐐           499      22599
#
#                     pubDate   type
# 0  2022-09-23T18:51:15.000Z  Photo
# 1  2022-09-22T21:29:52.000Z  Photo
# 2  2022-09-23T17:05:07.000Z  Photo
# 3  2022-09-23T17:20:03.000Z  Photo
# 4  2022-09-23T17:01:55.000Z  Video

# %%
df.pubDate= pd.to_datetime(df.pubDate).dt.date

# %%
#renaming description to caption

df.rename(columns = {'description':'caption'}, inplace = True)

# %%
df.head()
# Out:
#                                    postUrl  \
# 0  https://www.instagram.com/p/Ci3CTjkLyNs
# 1  https://www.instagram.com/p/Ci0vqfnKI58
# 2  https://www.instagram.com/p/Ci22KPwKtBr
# 3  https://www.instagram.com/p/Ci233mIqVch
# 4  https://www.instagram.com/p/Ci21u4rKV_K
#
#                                              caption  commentCount  likeCount  \
# 0  Stormzy styled by me in @maisonvalentino for #...            98      23380
# 1  We just step real clean and say Mel made me do...          1712      86221
# 2  Stormzy styled by me in @biancasaunders for #M...            41      13436
# 3  Dina Asher Smith in @area. Styled by me for St...            30      14227
# 4                                                🐐x🐐           499      22599
#
#       pubDate   type
# 0  2022-09-23  Photo
# 1  2022-09-22  Photo
# 2  2022-09-23  Photo
# 3  2022-09-23  Photo
# 4  2022-09-23  Video

# %%
df['date'] = pd.to_datetime(df['pubDate']) #transformed to datetime again?

# %%
df.head()
# Out:
#                                    postUrl  \
# 0  https://www.instagram.com/p/Ci3CTjkLyNs
# 1  https://www.instagram.com/p/Ci0vqfnKI58
# 2  https://www.instagram.com/p/Ci22KPwKtBr
# 3  https://www.instagram.com/p/Ci233mIqVch
# 4  https://www.instagram.com/p/Ci21u4rKV_K
#
#                                              caption  commentCount  likeCount  \
# 0  Stormzy styled by me in @maisonvalentino for #...            98      23380
# 1  We just step real clean and say Mel made me do...          1712      86221
# 2  Stormzy styled by me in @biancasaunders for #M...            41      13436
# 3  Dina Asher Smith in @area. Styled by me for St...            30      14227
# 4                                                🐐x🐐           499      22599
#
#       pubDate   type       date
# 0  2022-09-23  Photo 2022-09-23
# 1  2022-09-22  Photo 2022-09-22
# 2  2022-09-23  Photo 2022-09-23
# 3  2022-09-23  Photo 2022-09-23
# 4  2022-09-23  Video 2022-09-23

# %%
#add day of the week column
df["dotw"] =  df['date'].dt.day_name()

# %%
df.head()
# Out:
#                                    postUrl  \
# 0  https://www.instagram.com/p/Ci3CTjkLyNs
# 1  https://www.instagram.com/p/Ci0vqfnKI58
# 2  https://www.instagram.com/p/Ci22KPwKtBr
# 3  https://www.instagram.com/p/Ci233mIqVch
# 4  https://www.instagram.com/p/Ci21u4rKV_K
#
#                                              caption  commentCount  likeCount  \
# 0  Stormzy styled by me in @maisonvalentino for #...            98      23380
# 1  We just step real clean and say Mel made me do...          1712      86221
# 2  Stormzy styled by me in @biancasaunders for #M...            41      13436
# 3  Dina Asher Smith in @area. Styled by me for St...            30      14227
# 4                                                🐐x🐐           499      22599
#
#       pubDate   type       date      dotw
# 0  2022-09-23  Photo 2022-09-23    Friday
# 1  2022-09-22  Photo 2022-09-22  Thursday
# 2  2022-09-23  Photo 2022-09-23    Friday
# 3  2022-09-23  Photo 2022-09-23    Friday
# 4  2022-09-23  Video 2022-09-23    Friday

# %%
df['caption'] = df['caption'].astype(str) #convert to str to run code below

# %%
import re
def cleaner(txt):
  txt = re.sub(r'@[A-Za-z0-9_]+', '',txt)
  txt = re.sub(r'https?:\/\/[A-Aa-a0-9\.\/]+', '', txt)
  return txt

df["clean"] = df["caption"].map(lambda x: cleaner(x))

# %%
df.head()
# Out:
#                                    postUrl  \
# 0  https://www.instagram.com/p/Ci3CTjkLyNs
# 1  https://www.instagram.com/p/Ci0vqfnKI58
# 2  https://www.instagram.com/p/Ci22KPwKtBr
# 3  https://www.instagram.com/p/Ci233mIqVch
# 4  https://www.instagram.com/p/Ci21u4rKV_K
#
#                                              caption  commentCount  likeCount  \
# 0  Stormzy styled by me in @maisonvalentino for #...            98      23380
# 1  We just step real clean and say Mel made me do...          1712      86221
# 2  Stormzy styled by me in @biancasaunders for #M...            41      13436
# 3  Dina Asher Smith in @area. Styled by me for St...            30      14227
# 4                                                🐐x🐐           499      22599
#
#       pubDate   type       date      dotw  \
# 0  2022-09-23  Photo 2022-09-23    Friday
# 1  2022-09-22  Photo 2022-09-22  Thursday
# 2  2022-09-23  Photo 2022-09-23    Friday
# 3  2022-09-23  Photo 2022-09-23    Friday
# 4  2022-09-23  Video 2022-09-23    Friday
#
#                                                clean
# 0  Stormzy styled by me in  for #MelMadeMeDoIt \n...
# 1  We just step real clean and say Mel made me do...
# 2  Stormzy styled by me in  for #MelMadeMeDoIt\n\...
# 3  Dina Asher Smith in . Styled by me for Stormzy...
# 4                                                🐐x🐐

# %%
df.drop(["pubDate"], axis=1, inplace=True)

# %%
df["hashtags"] = df.caption.apply(lambda x: [x for x in x.split(" ") if x.startswith("#")])

# %%
df.sort_values(["date"], 
                    axis=0,
                    ascending=[True], 
                    inplace=True)

df.head()
# Out:
#                                     postUrl  \
# 48  https://www.instagram.com/p/CYPY465rJJY
# 47  https://www.instagram.com/p/CYT7SsLq9Zp
# 46  https://www.instagram.com/p/CYXRM6ZAqhn
# 45  https://www.instagram.com/p/CYg2rv4KSbq
# 44  https://www.instagram.com/p/CYq9CNiK1qQ
#
#                                               caption  commentCount  \
# 48                          Happiest at @vineaccra 🇬🇭           370
# 47                               Queen of green 🌿🌴🌱🦎🍃           376
# 46                            It girl energy always ✨           338
# 45                                  Good mood Melly 💚           131
# 44  I’ve been getting my @renskincare GLOW for yea...           275
#
#     likeCount   type       date       dotw  \
# 48      27803  Photo 2022-01-02     Sunday
# 47      25441  Photo 2022-01-04    Tuesday
# 46      21779  Photo 2022-01-05  Wednesday
# 45      17609  Photo 2022-01-09     Sunday
# 44      12410  Photo 2022-01-13   Thursday
#
#                                                 clean hashtags
# 48                                    Happiest at  🇬🇭       []
# 47                               Queen of green 🌿🌴🌱🦎🍃       []
# 46                            It girl energy always ✨       []
# 45                                  Good mood Melly 💚       []
# 44  I’ve been getting my  GLOW for years now and I...       []

# %%
#check for null
df.isnull()
#none found

# %%
#find max and min likes
max_likes = df["likeCount"].max()
min_likes = df["likeCount"].min()

print(max_likes)
print(min_likes)
# Out:
# 102959
# 4803

# %%
#find out which post had max and min likes

# %%
#find max and min comment
max_comments = df["commentCount"].max()
min_comments = df["commentCount"].min()

print(max_comments)
print(min_comments)
# Out:
# 7277
# 30

# %%
#find out which post had max and min comments
max_like = df[df["likeCount"] == 102959]
print(max_like)
# Out:
#                                     postUrl  \
# 26  https://www.instagram.com/p/CdqXRsgqoJR
#
#                                     caption  commentCount  likeCount   type  \
# 26  This is the peace that you cannot buy ✨           405     102959  Video
#
#          date     dotw                                    clean hashtags
# 26 2022-05-17  Tuesday  This is the peace that you cannot buy ✨       []

# %%
max_comment = df[df["commentCount"] == 7277]
print(max_comment)
# Out:
#                                     postUrl  \
# 30  https://www.instagram.com/p/Ccp5Hu9qf9_
#
#                               caption  commentCount  likeCount   type  \
# 30  It was always going to be a yes 💍          7277     102733  Photo
#
#          date    dotw                              clean hashtags
# 30 2022-04-22  Friday  It was always going to be a yes 💍       []

# %%
import numpy as np

#put max and min likes and comments in opaque bar graphs

term = ["max", "min"]
likes = [102959, 4803]
comments = [7277, 30]

x_axis = np.arange(len(term))

# Multi bar Chart

plt.bar(x_axis -0.2, likes, width=0.39, label = 'likes', color="green")
plt.bar(x_axis +0.2, comments, width=0.39, label = 'comments', color="orange")

# Xticks

plt.xticks(x_axis, term)
plt.legend()

plt.show()

# %%
#likes and comments trend this year

import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.plot(df["date"], df["commentCount"], label="comments", color="orange")
ax.plot(df["date"], df["likeCount"], label="likes", color="green")
plt.xlabel("date")
plt.ylabel("count")
plt.legend()
plt.title('Mels likes and comments 2022')
plt.show()

# %%
#add engagement column likes + comments 
df['engagement'] = df["likeCount"] + df["commentCount"]
df.head()
# Out:
#                                     postUrl  \
# 48  https://www.instagram.com/p/CYPY465rJJY
# 47  https://www.instagram.com/p/CYT7SsLq9Zp
# 46  https://www.instagram.com/p/CYXRM6ZAqhn
# 45  https://www.instagram.com/p/CYg2rv4KSbq
# 44  https://www.instagram.com/p/CYq9CNiK1qQ
#
#                                               caption  commentCount  \
# 48                          Happiest at @vineaccra 🇬🇭           370
# 47                               Queen of green 🌿🌴🌱🦎🍃           376
# 46                            It girl energy always ✨           338
# 45                                  Good mood Melly 💚           131
# 44  I’ve been getting my @renskincare GLOW for yea...           275
#
#     likeCount   type       date       dotw  \
# 48      27803  Photo 2022-01-02     Sunday
# 47      25441  Photo 2022-01-04    Tuesday
# 46      21779  Photo 2022-01-05  Wednesday
# 45      17609  Photo 2022-01-09     Sunday
# 44      12410  Photo 2022-01-13   Thursday
#
#                                                 clean hashtags  engagement
# 48                                    Happiest at  🇬🇭       []       28173
# 47                               Queen of green 🌿🌴🌱🦎🍃       []       25817
# 46                            It girl energy always ✨       []       22117
# 45                                  Good mood Melly 💚       []       17740
# 44  I’ve been getting my  GLOW for years now and I...       []       12685

# %%
df['avg_engagement'] = df.groupby('dotw').engagement.transform('mean')
df.head()
# Out:
#                                     postUrl  \
# 48  https://www.instagram.com/p/CYPY465rJJY
# 47  https://www.instagram.com/p/CYT7SsLq9Zp
# 46  https://www.instagram.com/p/CYXRM6ZAqhn
# 45  https://www.instagram.com/p/CYg2rv4KSbq
# 44  https://www.instagram.com/p/CYq9CNiK1qQ
#
#                                               caption  commentCount  \
# 48                          Happiest at @vineaccra 🇬🇭           370
# 47                               Queen of green 🌿🌴🌱🦎🍃           376
# 46                            It girl energy always ✨           338
# 45                                  Good mood Melly 💚           131
# 44  I’ve been getting my @renskincare GLOW for yea...           275
#
#     likeCount   type       date       dotw  \
# 48      27803  Photo 2022-01-02     Sunday
# 47      25441  Photo 2022-01-04    Tuesday
# 46      21779  Photo 2022-01-05  Wednesday
# 45      17609  Photo 2022-01-09     Sunday
# 44      12410  Photo 2022-01-13   Thursday
#
#                                                 clean hashtags  engagement  \
# 48                                    Happiest at  🇬🇭       []       28173
# 47                               Queen of green 🌿🌴🌱🦎🍃       []       25817
# 46                            It girl energy always ✨       []       22117
# 45                                  Good mood Melly 💚       []       17740
# 44  I’ve been getting my  GLOW for years now and I...       []       12685
#
#     avg_engagement
# 48    37429.000000
# 47    33191.000000
# 46    17552.272727
# 45    37429.000000
# 44    27844.500000

# %%
plt.bar(df["dotw"], df["avg_engagement"], color="green")
plt.title("Average engagement per day of the week") 
plt.xlabel("day of the week")
plt.ylabel("average engagement") 
plt.xticks(rotation = 90)
plt.show()

# %%
#add impressions column engagement * her followers
df['estimated_impressions'] =  df["engagement"] * 290000
df.head()
# Out:
#                                     postUrl  \
# 48  https://www.instagram.com/p/CYPY465rJJY
# 47  https://www.instagram.com/p/CYT7SsLq9Zp
# 46  https://www.instagram.com/p/CYXRM6ZAqhn
# 45  https://www.instagram.com/p/CYg2rv4KSbq
# 44  https://www.instagram.com/p/CYq9CNiK1qQ
#
#                                               caption  commentCount  \
# 48                          Happiest at @vineaccra 🇬🇭           370
# 47                               Queen of green 🌿🌴🌱🦎🍃           376
# 46                            It girl energy always ✨           338
# 45                                  Good mood Melly 💚           131
# 44  I’ve been getting my @renskincare GLOW for yea...           275
#
#     likeCount   type       date       dotw  \
# 48      27803  Photo 2022-01-02     Sunday
# 47      25441  Photo 2022-01-04    Tuesday
# 46      21779  Photo 2022-01-05  Wednesday
# 45      17609  Photo 2022-01-09     Sunday
# 44      12410  Photo 2022-01-13   Thursday
#
#                                                 clean hashtags  engagement  \
# 48                                    Happiest at  🇬🇭       []       28173
# 47                               Queen of green 🌿🌴🌱🦎🍃       []       25817
# 46                            It girl energy always ✨       []       22117
# 45                                  Good mood Melly 💚       []       17740
# 44  I’ve been getting my  GLOW for years now and I...       []       12685
#
#     avg_engagement  estimated_impressions
# 48    37429.000000             8170170000
# 47    33191.000000             7486930000
# 46    17552.272727             6413930000
# 45    37429.000000             5144600000
# 44    27844.500000             3678650000

# %%
# !pip install sklearn

# %%
#predicting reach following https://thecleverprogrammer.com/2022/03/22/instagram-reach-analysis-using-python/

from sklearn.model_selection import train_test_split

x = np.array(df[['likeCount', 'commentCount', 'avg_engagement']])
y = np.array(df["estimated_impressions"])
xtrain, xtest, ytrain, ytest = train_test_split(x, y, 
                                                test_size=0.2, 
                                                random_state=42)

# %%
from sklearn.linear_model import PassiveAggressiveRegressor

model = PassiveAggressiveRegressor()
model.fit(xtrain, ytrain)
model.score(xtest, ytest)
# Out:
# 0.9998541957905963

# %%
# Features = [['likeCount', 'commentCount', 'avg_engagement']]
features = np.array([[27803, 370, 28173]])
model.predict(features)
# Out:
# array([8.16498154e+09])
